# %%
# Step 1: Import required libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv("Result.csv")

# %%
print("Dataset Shape:", df.shape)

print("\nFirst 5 rows:")
display(df.head())
# Out:
# Dataset Shape: (1000, 9)
#
# First 5 rows:
#    Student_ID Gender  Study_Hours  Attendance  Math_Score  Science_Score  \
# 0           1      M         3.40          57          58           50.0
# 1           2      F         3.04          98          88           93.0
# 2           3      M         4.10          64          76           65.0
# 3           4      M         2.30          66          46           91.0
# 4           5      M         3.04          72          51           71.0
#
#    Sleep_Hours  Internet_Usage_Hours Final_Result
# 0         4.90                     6         Pass
# 1         6.91                     2         Pass
# 2         6.10                     5         Pass
# 3         6.80                     7         Pass
# 4         6.80                     2         Pass

# %%
print("\nColumn Information:")
print(df.info())
# Out:
# Column Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            1000 non-null   int64
#  1   Gender                1000 non-null   object
#  2   Study_Hours           1000 non-null   float64
#  3   Attendance            1000 non-null   int64
#  4   Math_Score            1000 non-null   int64
#  5   Science_Score         1000 non-null   float64
#  6   Sleep_Hours           1000 non-null   float64
#  7   Internet_Usage_Hours  1000 non-null   int64
#  8   Final_Result          1000 non-null   object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 70.4+ KB
# None

# %%
print("\nFinal_Result values:")
print(df["Final_Result"].value_counts())
# Out:
# Final_Result values:
# Final_Result
# Pass    756
# Fail    244
# Name: count, dtype: int64

# %%
target = "Science_Score"

# Numerical academic/lifestyle predictors
features = [
    "Study_Hours",
    "Attendance",
    "Math_Score",
    "Sleep_Hours",
    "Internet_Usage_Hours"
]

X = df[features]
y = df[target]

# %%
print("\nMissing values:")
print(df[features + [target]].isnull().sum())
# Out:
# Missing values:
# Study_Hours             0
# Attendance              0
# Math_Score              0
# Sleep_Hours             0
# Internet_Usage_Hours    0
# Science_Score           0
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("\nTraining samples:", len(X_train))
print("Testing samples:", len(X_test))
# Out:
# Training samples: 800
# Testing samples: 200

# %%
model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))

r2 = r2_score(y_test, y_pred)

# %%
print("\n============================================")
print("MULTIPLE LINEAR REGRESSION RESULTS")
print("============================================")

print("Target Variable:", target)
print("Predictor Variables:", features)

print("\nMAE  :", mae)
print("RMSE :", rmse)
print("R²   :", r2)
# Out:
# ============================================
# MULTIPLE LINEAR REGRESSION RESULTS
# ============================================
# Target Variable: Science_Score
# Predictor Variables: ['Study_Hours', 'Attendance', 'Math_Score', 'Sleep_Hours', 'Internet_Usage_Hours']
#
# MAE  : 16.134665812862668
# RMSE : 19.393442874050102
# R²   : 0.0062931021781668095

# %%
print("\nRegression Coefficients:")

coefficients = pd.DataFrame({
    "Feature": features,
    "Coefficient": model.coef_
})

display(coefficients)

print("Intercept:", model.intercept_)
# Out:
# Regression Coefficients:
#                 Feature  Coefficient
# 0           Study_Hours    -0.587276
# 1            Attendance     0.048481
# 2            Math_Score     0.018170
# 3           Sleep_Hours    -0.290785
# 4  Internet_Usage_Hours    -0.219191
# Intercept: 65.27198289678276

# %%
results = pd.DataFrame({
    "Actual Science Score": y_test.values,
    "Predicted Science Score": y_pred
})

display(results.head(10))
# Out:
#    Actual Science Score  Predicted Science Score
# 0                  42.0                62.976946
# 1                  86.0                66.334018
# 2                  61.0                65.083627
# 3                  31.0                62.803520
# 4                  87.0                65.000089
# 5                  36.0                65.381230
# 6                  97.0                64.661359
# 7                  50.0                65.581249
# 8                  65.0                65.751507
# 9                  34.0                65.698701
